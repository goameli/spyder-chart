# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from math import pi

# %%
df = pd.DataFrame({
'group': ['A','B','C','D'],
'speed': [38, 1.5, 30, 4],
'tension': [29, 10, 9, 34],
'torq': [8, 39, 23, 24],
'kpi': [7, 31, 33, 14],
'number': [28, 15, 32, 14]
})

# %%
df
# Out:
#   group  speed  tension  torq  kpi  number
# 0     A   38.0       29     8    7      28
# 1     B    1.5       10    39   31      15
# 2     C   30.0        9    23   33      32
# 3     D    4.0       34    24   14      14

# %%
df.mean()
# Out:
# speed      18.375
# tension    20.500
# torq       23.500
# kpi        21.250
# number     22.250
# dtype: float64

# %%
categories = list(df)[1:]

# %%
categories
# Out:
# ['speed', 'tension', 'torq', 'kpi', 'number']

# %%
values = df.mean().values.flatten().tolist()
values += values[:1] # repeat the first value to close the circular graph
angles = [n / float(len(categories)) * 2 * pi for n in range(len(categories))]
angles += angles[:1]

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 8),
                       subplot_kw=dict(polar=True))

plt.xticks(angles[:-1], categories, color='grey', size=10)
plt.yticks(np.arange(1, 10), ['5', '10', '15', '20', '25'],
           color='grey', size=12)
plt.ylim(0, 30)
ax.set_rlabel_position(30)
 
ax.plot(angles, values, linewidth=1, linestyle='solid')
ax.fill(angles, values, 'skyblue', alpha=0.4)

plt.show()

# %%
array=[[0.88, 0.85, 0.83, 0.94, 0.77],
       [0.84, 0.77, 0.75, 0.84, 0.66],
       [1., 1., 1., 1., 1., 1.],
       [0.84, 0.88, 0.86, 0.95, 0.77],
       [0., 0., 0., 0., 0.],
       [0.98, 0.68, 0.78, 0.75, 0.70]]

# %%
categories=['Speed', 'Torque', 'Power', 'Load', 'Output']

# %%
mean_B108=[array[1][0], array[1][1], array[1][2], array[1][3], array[1][4]]
mean_B108=np.concatenate((mean_B108, [mean_B108[0]]))

# %%
best_B108=[array[0][0], array[0][1], array[0][2], array[0][3], array[0][4]]
best_B108=np.concatenate((best_B108, [best_B108[0]]))

# %%
best_neu=[array[3][0], array[3][1], array[3][2], array[3][3], array[3][4]]
best_neu=np.concatenate((best_neu, [best_neu[0]]))

# %%
label_placement = np.linspace(start=0, stop=2*np.pi,num=len(mean_B108))

# %%
plt.figure(figsize=(6,6))
plt.subplot(polar=True)
plt.plot(label_placement,best_B108, 'r')
plt.plot(label_placement,best_neu, 'g')
plt.plot(label_placement, mean_B108, 'y')

lines, labels = plt.thetagrids(np.degrees(label_placement), labels=categories)
plt.title('B_108', y=1.1, fontdict={"fontsize":18})
plt.legend(labels={"mean_B108", "best_B108", "best_neu"})
